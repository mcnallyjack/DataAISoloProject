# %%
import numpy as np
import pandas as pd
import os

# %%
data1 = pd.read_csv('/home/jack/DataSolo/DecisionTree/test.csv')

# %%
data1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               NaN         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
data2 = pd.read_csv('/home/jack/DataSolo/DecisionTree/train.csv')

# %%
data2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
data = [data1, data2]

# %%
combine = pd.DataFrame()

# %%
combine = pd.concat(data, sort=True)

# %%
combine.to_csv('/home/jack/DataSolo/DecisionTree/combine.csv', index=False)

# %%
LoanApproval = pd.read_csv('/home/jack/DataSolo/DecisionTree/combine.csv')

# %%
LoanApproval
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5720                0.0             1.0          0
# 1               3076             1500.0             1.0          1
# 2               5000             1800.0             1.0          2
# 3               2340             2546.0             NaN          2
# 4               3276                0.0             1.0          0
# ..               ...                ...             ...        ...
# 976             2900                0.0             1.0          0
# 977             4106                0.0             1.0         3+
# 978             8072              240.0             1.0          1
# 979             7583                0.0             1.0          2
# 980             4583                0.0             0.0          0
#
#         Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0        Graduate    Male       110.0             360.0  LP001015         NaN
# 1        Graduate    Male       126.0             360.0  LP001022         NaN
# 2        Graduate    Male       208.0             360.0  LP001031         NaN
# 3        Graduate    Male       100.0             360.0  LP001035         NaN
# 4    Not Graduate    Male        78.0             360.0  LP001051         NaN
# ..            ...     ...         ...               ...       ...         ...
# 976      Graduate  Female        71.0             360.0  LP002978           Y
# 977      Graduate    Male        40.0             180.0  LP002979           Y
# 978      Graduate    Male       253.0             360.0  LP002983           Y
# 979      Graduate    Male       187.0             360.0  LP002984           Y
# 980      Graduate  Female       133.0             360.0  LP002990           N
#
#     Married Property_Area Self_Employed
# 0       Yes         Urban            No
# 1       Yes         Urban            No
# 2       Yes         Urban            No
# 3       Yes         Urban            No
# 4        No         Urban            No
# ..      ...           ...           ...
# 976      No         Rural            No
# 977     Yes         Rural            No
# 978     Yes         Urban            No
# 979     Yes         Urban            No
# 980      No     Semiurban           Yes
#
# [981 rows x 13 columns]

# %%
LoanApproval = LoanApproval.sort_values(LoanApproval['Loan_ID'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-004d5e77ffce> in <module>
# ----> 1 LoanApproval = LoanApproval.sort_values(LoanApproval['Loan_ID'], ascending=False)
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 0      LP001015
# 1      LP001022
# 2      LP001031
# 3      LP001035
# 4      LP001051
#          ...
# 976    LP002978
# 977    LP002979
# 978    LP002983
# 979    LP002984
# 980    LP002990
# Name: Loan_ID, Length: 981, dtype: object

# %%
test = LoanApproval

# %%
test
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5720                0.0             1.0          0
# 1               3076             1500.0             1.0          1
# 2               5000             1800.0             1.0          2
# 3               2340             2546.0             NaN          2
# 4               3276                0.0             1.0          0
# ..               ...                ...             ...        ...
# 976             2900                0.0             1.0          0
# 977             4106                0.0             1.0         3+
# 978             8072              240.0             1.0          1
# 979             7583                0.0             1.0          2
# 980             4583                0.0             0.0          0
#
#         Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0        Graduate    Male       110.0             360.0  LP001015         NaN
# 1        Graduate    Male       126.0             360.0  LP001022         NaN
# 2        Graduate    Male       208.0             360.0  LP001031         NaN
# 3        Graduate    Male       100.0             360.0  LP001035         NaN
# 4    Not Graduate    Male        78.0             360.0  LP001051         NaN
# ..            ...     ...         ...               ...       ...         ...
# 976      Graduate  Female        71.0             360.0  LP002978           Y
# 977      Graduate    Male        40.0             180.0  LP002979           Y
# 978      Graduate    Male       253.0             360.0  LP002983           Y
# 979      Graduate    Male       187.0             360.0  LP002984           Y
# 980      Graduate  Female       133.0             360.0  LP002990           N
#
#     Married Property_Area Self_Employed
# 0       Yes         Urban            No
# 1       Yes         Urban            No
# 2       Yes         Urban            No
# 3       Yes         Urban            No
# 4        No         Urban            No
# ..      ...           ...           ...
# 976      No         Rural            No
# 977     Yes         Rural            No
# 978     Yes         Urban            No
# 979     Yes         Urban            No
# 980      No     Semiurban           Yes
#
# [981 rows x 13 columns]

# %%
test = pd.DataFrame(LoanApproval, columns=['Loan_ID'])

# %%
test
# Out:
#       Loan_ID
# 0    LP001015
# 1    LP001022
# 2    LP001031
# 3    LP001035
# 4    LP001051
# ..        ...
# 976  LP002978
# 977  LP002979
# 978  LP002983
# 979  LP002984
# 980  LP002990
#
# [981 rows x 1 columns]

# %%
dupTest = test[test.duplicated(['Loan_ID'])]

# %%
dupTest
# Out:
# Empty DataFrame
# Columns: [Loan_ID]
# Index: []

# %%
LoanApproval
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5720                0.0             1.0          0
# 1               3076             1500.0             1.0          1
# 2               5000             1800.0             1.0          2
# 3               2340             2546.0             NaN          2
# 4               3276                0.0             1.0          0
# ..               ...                ...             ...        ...
# 976             2900                0.0             1.0          0
# 977             4106                0.0             1.0         3+
# 978             8072              240.0             1.0          1
# 979             7583                0.0             1.0          2
# 980             4583                0.0             0.0          0
#
#         Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0        Graduate    Male       110.0             360.0  LP001015         NaN
# 1        Graduate    Male       126.0             360.0  LP001022         NaN
# 2        Graduate    Male       208.0             360.0  LP001031         NaN
# 3        Graduate    Male       100.0             360.0  LP001035         NaN
# 4    Not Graduate    Male        78.0             360.0  LP001051         NaN
# ..            ...     ...         ...               ...       ...         ...
# 976      Graduate  Female        71.0             360.0  LP002978           Y
# 977      Graduate    Male        40.0             180.0  LP002979           Y
# 978      Graduate    Male       253.0             360.0  LP002983           Y
# 979      Graduate    Male       187.0             360.0  LP002984           Y
# 980      Graduate  Female       133.0             360.0  LP002990           N
#
#     Married Property_Area Self_Employed
# 0       Yes         Urban            No
# 1       Yes         Urban            No
# 2       Yes         Urban            No
# 3       Yes         Urban            No
# 4        No         Urban            No
# ..      ...           ...           ...
# 976      No         Rural            No
# 977     Yes         Rural            No
# 978     Yes         Urban            No
# 979     Yes         Urban            No
# 980      No     Semiurban           Yes
#
# [981 rows x 13 columns]

# %%
data2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
LoanApproval = data2

# %%
LoanApproval
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
LoanApproval.to_csv('/home/jack/DataSolo/DecisionTree/FinalDT.csv', index=False)

# %%
LoanApproval.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object
