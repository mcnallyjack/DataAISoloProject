# %% [markdown]
# # Decision Tree Revision Tutorial

# %% [markdown]
# <hr>

# %% [markdown]
# #### Name : Jack McNally
# #### Student Number : C00228758
# #### Lecturer : Greg Doyle

# %% [markdown]
# <hr>

# %% [markdown]
# ## Table of Contents
# * [Introduction](#Introduction)
# * [Decision Trees](#DecisonTrees)
# * [Random Forest](#RandomForest)
# * [Neural Networks](#NeuralNetworks)
# * [Linear Regression](#LinearRegression)
# * [Conclusion](#Conclusion)
# * [Declaration](#Declaration)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Introduction <a class="anchor" id="Introduction"></a>

# %% [markdown]
# <p> The intended purpose of this report documentation is to display the understanding and knowledge gained through implementing various different machine learning algorithms.
#
#
#
# The algorithms that will be included in this report will be based on algorithms that have been learned throughout the year and then implemented into this report. Each algorithm will be explained in multiple sections including a quick introduction, the data pre-processing required, results of the algorithm and the quality of the outcome. After each algorithm has been implemented and explained, a Jupyter notebook will be created to easily display how the whole process was implemented and how the final result was achieved.
#
#
#
# The main learning outcome of the report is to gain a much greater understanding of these specific machine learning algorithms and how they work. This is very beneficial as the Data side of the software industry is ever growing and is important that the knowledge and knowhow of data science is gained before entering the workforce.
#
# The four algorithms that I have chosen are
#
# 1. Decision Trees
# 2. Random Forest
# 3. Neural Networks
# 4. Linear Regression

# %% [markdown]
# <hr>

# %% [markdown]
# ### Decision Trees  <a class="anchor" id="DecisionTrees"></a>
# * [Introduction](#IntroDecTree)
# * [Sources Of Information](#InfoDecTree)
# * [Problem](#ProbDecTree)
# * [Data Pre-processing](#DataDecTree)
# * [Main Algorithm](#MainDecTree)
# * [Conclusion + Quality](#ConDecTree)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Introduction <a class="anchor" id="IntroDecTree"><a/>

# %% [markdown]
# The Decision Tree machine learning algorithm is a predictive approach used in Machine Learning. In simple terms a decision tree takes a large dataset and divides it into progressively smaller datasets using a particular set of decision rules [1].
#
#
#
# Decision Trees or DT’s as they are sometimes referred to are a non-parametric model. This means that you may not know the normal distribution of the dataset. Decision Trees can be used for both Regression and Classification models which is rather helpful because classification is about predicting a label while regression is about predicting a quantity. The fact that both models can be predicted using decision trees renders it rather powerful in machine learning [2].
#
#
#
# Decision trees do require some key values to come to fruition such as [3];
#
#
#
# - <b> Attribute Value Description </b> = the object must be expressible in a fixed collection of attributes. E.g. Cold or Warm. <br>
# - <b> Sufficient Data</b>  = enough data must be provided so the model can be as accurate as possible. <br>
# - <b> Target Values </b>  = the target function has discrete output values.
#
#
#
# Decision Trees sometimes use builders. Builders are algorithms that have the ability to generate a tree. Some examples include Random Forrest, Classification and Regression Trees (CART), ID3 and C4.5. One of the most influential algorithms is the CART algorithm and this is the algorithm that will demoed later on in this section.

# %% [markdown]
# ![image.png](attachment:image.png) <i>Decision Tree [10]</i>

# %% [markdown]
#  <h4> Different Decision Tree Algorithms </h4>
#
#  - <b>CART Algorithm </b>
#
# The CART algorithm or the Classification and Regression Tree algorithm introduced by Leo Breiman [8] is a non-parametric algorithm that produces classification or regression trees.
#
# The algorithm uses Gini impurity is used to decide the optimal split of the root node. Gini impurity displays the probability of misclassifying an observation [9].
#
# The CART algorithm will be the algorithm that will be demoed for decision trees. The data pre-processing and the main algorithm will be demonstrated using Entropy and Gini-impurity to see which method more suits the dataset.
#
# - <b>ID3 Algorithm</b>
#
# The ID3 algorithm is an algorithm created by Ross Quinlan and is used to generate a tree from a dataset.
#
# This Algorithm gets its name from what it actually does, “Iterative Dichotomiser” or in plainer terms “Repetitively Dividing” basically divides the values into two or more groups at each step.
#
# The main method of decision making the ID3 algorithms uses is “Entropy”. Entropy is the measure of the amount of uncertainty in a dataset. For example, if the values are always the same e.g. answers to a question is always “No” the entropy is said to be low, but if the values are different, e.g. the answers are “Yes”, “No”, “Unknown” the entropy is said to be High and this is when it is most effective [4].
#
# - <b>C4.5 Algorithm </b>
#
# Another algorithm that is used to create decision trees is the C4.5 algorithm this algorithm is the precursor to the ID3 algorithm.
#
# The C4.5 algorithms which was once again created by Ross Quinlan is an improved version of the ID3 algorithm, the C4.5 algorithm offers these key improvements [5];
#
#    - C4.5 handles both continuous and discrete data, in order to handle continuous data C4.5 creates a threshold and separates the values into lists that are greater than an less than the thresholds.
#    - C4.5 marks the missing data as ‘?’ so they are not used in gain and entropy calculations.
#    - Lastly C4.5 prunes the tree after the creation. This means that the algorithm goes back through the tree and removes branches that are not necessary and replaces them with leaf nodes.
#
#
#
# - <b> Advantages of Decision Trees</b>
#
#     - Decision trees one of the more easier to understand algorithms and most people can understand them after a brief explanation [6].
#
#     - The best, worst and expect values can all be predicted using this algorithm [6].
#
#     - The decision tree algorithm can be combined with other algorithms [6].
#
#
# - <b> Disadvantages of Decision Trees </b>
#
#    -  The decision tree algorithm can be unstable, if the value change even the smallest amount the whole algorithm can be thrown off course [7].
#
#    - The calculations associated with decision trees can sometimes be very complex and difficult to understand [7].
#    - Decision tree training takes more time and is relatively expensive in terms of time and complexity [7].

# %% [markdown]
# <hr>

# %% [markdown]
# ### Sources Of Information <a class="anchor" id="InfoDecTree"><a/>

# %% [markdown]
# This section contains the references to the above information and can be accessed by simply clicking the link provided or just copying the provided link. This information was used alongside information that was gained through learning the decision tree algorithm during lectures. This section also contains link to tutorials that I followed to get a greater understanding of Decision Trees.
#
#
#
# <b>[1]  </b> <sp>Wikipedia     (2020).    Decision Tree Learning    [online] <br>
#                     Available at: https://en.wikipedia.org/wiki/Decision_tree_learning [Accessed on 22nd Dec 2020.]
#
# <b>[2] </b>  Machine Learning Mastery       (2020).   Difference between Classification and Regression in Machine Learning    [online] <br> Available at: https://machinelearningmastery.com/classification-versus-regression-in-machine-learning/ [Accessed on 22nd Dec 2020.]
#
#
# <b>[3]  </b> Greg Doyle (2020). Chapter 8 Decision Trees    [slides] <br>
# Available at: Blackboard.itcarlow.ie [Accessed on 22nd Dec 2020.]
#
#
# <b>[4] </b>       Towards Data Science                    (2020).           ID3 Algorithm Explained     [online]      <br>     Available at: https://towardsdatascience.com/decision-trees-for-classification-id3-algorithm-explained-89df76e72df1 [Accessed on 23rd Dec 2020.]
#
#
# <b>[5]</b>      Wikipedia                   (2020).           C4.5 Algorithm                     [online]
# <br>Available at: https://en.wikipedia.org/wiki/C4.5_algorithm [Accessed on 23rd Dec 2020.]
#
#
#
# <b>[6]</b>        Wikipedia                   (2020).           Decision Tree                       [online]
# <br>Available at: https://en.wikipedia.org/wiki/Decision_tree [Accessed on 23rd Dec 2020.]
#
#
#
# <b>[7]</b>        DhirajK                       (2020).           Top 5 Advantages and Disadvantages of Decision Tree Algorithm    [online] <br>Available at: https://dhirajkumarblog.medium.com/top-5-advantages-and-disadvantages-of-decision-tree-algorithm-428ebd199d9a [Accessed on 23rd Dec 2020.]
#
#
#
# <b>[8]</b>        Machine learning mastery              (2020).           Classification and Regression for machine learning      [online]       <br>     Available at:  https://machinelearningmastery.com/classification-and-regression-trees-for-machine-learning/ [Accessed on 27th Dec 2020].
#
# <b>[9]</b>        Wikipedia       (2020).           Decision tree learning         [online]
# <br>Available at: https://en.wikipedia.org/wiki/Decision_tree_learning [Accessed on 28th Dec 2020].
#
#
# <b>[10]</b> Research Gate (2020). A simple Decsion Tree  [online] <br> Available at: https://www.researchgate.net/figure/A-simple-decision-tree-Leaves-represent-the-2-classes-Play-or-Dont-Play-referring-to_fig8_279398111 [Accessed on 28th Dec 2020].
#
# <hr>
#
# <h4> Some tutorials I used that helped me </h4>
#
# HackerEarth (2020). Decison Tree [online] <br> Available at: https://www.hackerearth.com/practice/machine-learning/machine-learning-algorithms/ml-decision-tree/tutorial/ [Accessed on 29th Dec 2020].
#
# Datacamp (2021). Decision Tree Classification in Python [online] <br> Available at: https://www.datacamp.com/community/tutorials/decision-tree-classification-python [Accessed on 2nd January 2021].

# %% [markdown]
# <hr>

# %% [markdown]
# ### Problem <a class="anchor" id="ProbDecTree"></a>

# %% [markdown]
# The problem that I have decided to work on for my Decision Tree tutorial is regarding Loan Approvals. The dataset that I have found has a series of data regarding loan approvals which will be discussed below.
#
#
#
# I believe that this problem is a very understandable issue and people will be able to understand all of the decisions in the dataset.
#
# Also an additional note, I will be using the CART algorithm for the main algorithm

# %% [markdown]
# <hr>

# %% [markdown]
# ### Data Pre-processing <a class="anchor" id="DataDecTree"><a/>

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pandas as pd
import os
from sklearn import tree
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In the next section I will demonstrate how I imported the dataset that I am going to use to demonstrate Decision Trees. I will then show how I handle the null values present, then finally I will explore the dataset.
#
# The data can be downloaded here: https://github.com/ParthS007/Loan-Approval-Prediction/blob/master/train.csv

# %% [markdown]
# <hr>

# %% [markdown]
# #### Import the Datasets

# %% [markdown]
# <font color='red'>If the dataset is not getting imported correctly, Please change the path</font>

# %%
LoanApproval = pd.read_csv('/home/jack/DataSolo/DecisionTree/train.csv')

# %%
LoanApproval.dtypes

# %%
LoanApproval.head(5)

# %% [markdown]
# The columns in the dataset are as follows,
# - Loan_ID - number.
# - Gender – Male / Female.
# - Married – Yes / No.
# - Dependants – 0 / 1 / 2 / 3+
# - Education – Graduate / Non-Graduate
# - Self-Employed – Yes / No
# - Applicant Income – number.
# - Co-Applicant Income – number.
# - Loan Amount – number.
# - Loan Amount term – number
# - Credit History -  Yes / No
# - Property Area – Urban / Semi-Urban / Rural.
# - Loan Status – Yes / No.

# %% [markdown]
# As can be seen above the dataset and a sample of data. The "LoanApproval.head(5)" shows the first 5 rows of data
#
# I will now demonstrate how I handle the null values present in the dataset before exploring the dataset.
#
# <hr>
#
# <h4> Null Value Replacement </h4>

# %% [markdown]
# As can be seen in the cell below the dataset has some null values, we will handle them using an average replacement method, this involves getting the average value of the column and then filling the null values with the average value. The following cells will display finding the mean value and also the replacements.

# %%
LoanApproval.isnull().sum()

# %%
LoanApproval['Gender'].str.contains('Female').sum()

# %% [markdown]
# This means that Female occurs only '112' times in the dataset, while male appears '488' times. Therefore I will replace the Null values with female.

# %%
LoanApproval['Gender'] = LoanApproval['Gender'].fillna("Female")

# %%
LoanApproval.isnull().sum()

# %% [markdown]
# Now you see that the Gender column has no null values, I will now repeat this for all of the remaining columns that have null values present.

# %%
LoanApproval['Married'] = LoanApproval['Married'].fillna("No")
LoanApproval['Dependents'] = LoanApproval['Dependents'].fillna('3')
LoanApproval['Self_Employed'] = LoanApproval['Self_Employed'].fillna("Yes")
LoanApproval['LoanAmount'] = LoanApproval['LoanAmount'].fillna('66.0')
LoanApproval['Loan_Amount_Term'] = LoanApproval['Loan_Amount_Term'].fillna('270.0')
LoanApproval['Credit_History'] = LoanApproval['Credit_History'].fillna('0.0')

# %%
LoanApproval.isnull().sum()

# %% [markdown]
# <hr>

# %% [markdown]
# #### Converting to binary

# %% [markdown]
# As you can see in the cell above the dataset now has no null values. I will now move onto converting the string decisons to binary decisions, e.g. Male will become 1 and Female will become 0. This process can be completed using the LabelEncoder function but some columns do not need to be changed, Therefore I will complete this process manually.

# %%
LoanApproval['Gender'] = LoanApproval['Gender'].map(dict(Male=1,Female=0))
LoanApproval['Married'] = LoanApproval['Married'].map(dict(Yes=1,No=0))
LoanApproval['Education'] = LoanApproval['Education'].eq('Graduate').mul(1.0)
LoanApproval['Self_Employed'] = LoanApproval['Self_Employed'].eq('Yes').mul(1.0)
LoanApproval['Property_Area'] = LoanApproval['Property_Area'].map(dict(Urban=1,Rural=0,Semiurban=2))
LoanApproval['Dependents'] = LoanApproval['Dependents'].eq('3+').mul(3.0)
LoanApproval['Loan_Status'] = LoanApproval['Loan_Status'].map(dict(Y=1,N=0))

# %% [markdown]
# <hr>

# %% [markdown]
# #### Exploring the Data
#
# I will now explore the dataset, it is important to explore the dataset after the binary conversions and null value replacement have been completed. In this section I will generate graphs that correspond to the data I am using and help gain a greater understand of the dataset and problem.

# %%
import seaborn as sb
LoanApproval = LoanApproval.drop(0)

# %% [markdown]
# In the following graph I am going to explore the Applicant Income. This column stands out as a key column that will help visualize the dataset and also it is a key value as Loan Approvals often boil down to how much the Applicant earns.

# %%
import matplotlib as mpl
plt.figure(figsize=(8,6))
sb.histplot(x=LoanApproval['ApplicantIncome'], hue=LoanApproval['Loan_Status'], palette="dark")
plt.ylabel("Number of Loans")
plt.show()

# %% [markdown]
# As can be seen in the graph above
# - <b> 1 </b> = Yes (Got a Loan)
# - <b> 0 </b> = No (Did not get a Loan)
#
# Also in the graph above it can be seen that there is quite alot of outlier data and this can bring down the overall accuracy of the model. In the following sections I will display a method to remove the outlier data.

# %% [markdown]
# <hr>

# %% [markdown]
# #### 1. Get the Max Value of the Column

# %%
LoanApproval['ApplicantIncome'].max()

# %% [markdown]
# In the following cell, any value in the "Applicant Income" column that is > '20000' index is stored

# %%
inName = LoanApproval[ LoanApproval['ApplicantIncome'] > 20000 ].index

# %% [markdown]
# <hr>

# %% [markdown]
# #### 2. Drop the Values

# %%
LoanApproval = LoanApproval.drop(inName)

# %%
plt.figure(figsize=(10,6))
sb.histplot(x=LoanApproval['ApplicantIncome'], hue=LoanApproval['Loan_Status'], palette="dark")
plt.show()

# %% [markdown]
# As can be seen in the graph above
# - <b> 1 </b> = Yes (Got a Loan)
# - <b> 0 </b> = No (Did not get a Loan)
#
# As you can see in the new graph the extreme outlier data has been removed. This will help improve the accuary of the model.

# %% [markdown]
# We will now explore another section of the dataset and this will involve the Self_Employed column. This is another key columns that will help us understand the dataset better.

# %%
plt.figure(figsize=(4,6))
sb.histplot(x=LoanApproval['Self_Employed'], hue=LoanApproval['Loan_Status'], palette="dark")
plt.show()

# %% [markdown]
# As can be seen in the graph above
# - <b> 1 </b> = Yes (Got a Loan)
# - <b> 0 </b> = No (Did not get a Loan)
#
# - <b> 0.0  </b> = Not self-emloyed
# - <b> 1.0 </b> = Self-Employed
#
# As you can see in the graph about there is no outlier data, this is a good sign. This graph clearly visualises the the difference and a statement can be made "that around half the people self-employed or not will get a loan"
#
# Now that we have explored the data and gained a greater understanding we will now move onto the Main algorithm.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Main Algorithm <a class="anchor" id="MainDecTree"><a/>

# %% [markdown]
# In this section of the tutorial I will now train the model to allow the algorithm to take place. The first step of this process is to identify my features and then my main value. In this case I have chosen Loan_Status as my main value, the reasoning behind this because my problem is Loan Approvals the Loan status signifies if they got the Loan or not.
#
# I will then use the remaining columns as the features, excluding the Co-applicant Income. The reasoning for this is there is too much empty values in this column and it would hinder the preformance of the model.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Spliting the Data

# %%
features = ['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area']
x = LoanApproval[features]
y = LoanApproval.Loan_Status
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=1)

# %% [markdown]
# As you can see above I set <b>X</b> to the feature list and then<b> y </b> to Loan Status, I then split the data using <b> train_test_split </b> this function takes in the X and y values and also a series of parameters to split the data

# %% [markdown]
# <hr>

# %% [markdown]
# #### Training the model

# %%
cl = DecisionTreeClassifier()
cl = cl.fit(x_train,y_train)
y_pred = cl.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# As you can see above I have trained the model using <b> DecisionTreeClassifer </b> this is a function that takes our data and creates and runs the decison trees.
#
# After executing the algorithm, the accuracy of this model is below 72%. This is a bad accuracy. In the following cell I will display an actual visualization of the Decision Tree that has been created from the model.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Visualization

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(cl, 
                   feature_names=features,  
                   
                   filled=True)

# %% [markdown]
# I will now attempt to tune the model to see if i can imporove the accuracy. As you can see in the cell below the method in which this is done is by chnaging the parameters in the "DecisionTreeClassifier" function.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Re-training the model

# %% [markdown]
# As you can see below I have changed the <b> DecisionTreeClassifier </b> parameters

# %%
cl = DecisionTreeClassifier(criterion='entropy',splitter='best',max_depth=3) 
cl = cl.fit(x_train,y_train)
y_pred = cl.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# As you can see the accuracy got worse using the new parameters.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Visualization

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(cl, 
                   feature_names=features,  
                   
                   filled=True)

# %% [markdown]
# In the following cells of the notebook I will attempt to hypetun the model. I will do this by applying pruning techniques as well as overfitting techniques.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Training the Model to get the highest accuracy

# %%
cl = DecisionTreeClassifier(random_state=3, criterion="gini", max_leaf_nodes=11, max_depth=4,min_samples_split=3) 
cl = cl.fit(x_train,y_train)
y_pred = cl.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)* 100)

# %% [markdown]
# As you can see after the complex hypertuning I have increase the accuracy to a reasonable 79%.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Visualisation

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(cl, 
                   feature_names=features,  
                   
                   filled=True)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Conclusion + Quality <a class="anchor" id="ConDecTree"><a/>

# %% [markdown]
# In conclusion, the decision tree machine learning algorithm is a very quick and accurate algorithm when used correctly. The results that were received from execution this algorithm were good according to machine learning standards.
#
# The decision tree algorithm is best used when the decision that need to be made are binary e.g. Yes or No as these can be converted to 1 or 0. Also the decision trees machine learning algorithm excels using numerical data.
#
# A large section of the algorithm was tuning the algorithm, in my case this involved much trial and error to get a proper understanding of each of the parameters.
#
# If I could change one thing about the method in which I implemented the decision tree machine learning algorithm it would be with a much larger dataset. This would particularly interesting as I would be able to see if the accuracy would significantly increase as I would be using much more data to train the model. But I using the dataset I used was perfectly adequate as it allowed me to portray the points I hoped to get across.
#
# <hr>

# %% [markdown]
# ### Random Forest  <a class="anchor" id="RandomForest"></a>
# * [Introduction](#IntroRanFor)
# * [Sources Of Information](#InfoRanFor)
# * [Problem](#ProbRanFor)
# * [Data Pre-processing](#DataRanFor)
# * [Main Algorithm](#MainRanFor)
# * [Conclusion + Quality](#ConRanFor)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Introduction <a class="anchor" id="IntroRanFor"></a>

# %% [markdown]
# The Random forests machine learning algorithm is a supervised machine learning algorithm that is an ensemble of decision of decision trees.[11] The overall goal of Random forests is to combine many decision trees to go get a much better result.
#
# Random forest like decision trees and many other algorithms can be used for Classification and Regression problems. As mentioned above Random forest use a method called "ensemble", this means that the Random forest classifer creates multiple decision trees and then selects the best solution by voting.[12]
#
# Random forests are very similar to Decision trees, Random forests needs to meet the following requirments to be created;
#
# - <b> Attribute Value Description </b> = the object must be expressible in a fixed collection of attributes. E.g. Cold or Warm. <br>
# - <b> Target Values </b>  = the target function has discrete output values.  <br>
# - <b> Feature Values</b>  = values thats the target value can be compared against

# %% [markdown]
# #### Bagging
# Bagging or (Bootstrap Aggregating) is a method used by Random forests to generate new datasets for a model. Bagging is a very important technique as it helps the Random forest algorithm to prevent overfitting. Overfitting is a big problem in Decision trees.[13]
#
# Bagging also helps the random forest algorithm become much more stable and much more accurate

# %% [markdown]
# ![image.png](attachment:image.png) <i>Random Forests [14]</i>

# %% [markdown]
# - <b> Advantages of Random forests</b>
#
#     - One of the most accurate machine learning algorithms and also works well on large datasets. [15]
#
#     - Flexiable to both Classification & Regression problems [16].
#
#     - Outputs the importance of Features [17].
#
#
# - <b> Disadvantages of Random forests </b>
#
#     - Random forests tend to overfit noisy datasts[15]
#
#     - Randoms forests result may change drastically if there is a small change in the data. [17]
#
#     - Take longer to train the model. [18]

# %% [markdown]
# <hr>

# %% [markdown]
# ### Sources Of Information <a class="anchor" id="InfoRanFor"></a>

# %% [markdown]
# This section contains the references to the above information and can be accessed by simply clicking the link provided or just copying the provided link. This information was used alongside information that was gained through learning the random forsest algorithm during lectures. This section also contains link to tutorials that I followed to get a greater understanding of Random forests.
#
#
# <b>[11]  </b> Builtin  (2021).  A complete guide to the random forest algorithm  [online] <br>
# Available at: https://builtin.com/data-science/random-forest-algorithm [Access on 5th January 2021]
#
# <b>[12] </b>  TowardsDataSciene (2021). Understanding Random Forest [online] <br>
# Available at: https://towardsdatascience.com/understanding-random-forest-58381e0602d2 [Accessed on 5th January 2021]
#
# <b> [13] </b> Oracle (2021). An Introduction To Building a Classification Model Using Random Forests In Python [online] <br>
# Available at: https://blogs.oracle.com/ai-and-datascience/post/an-introduction-to-building-a-classification-model-using-random-forests-in-python [Accessed on 6th January 2021]
#
# <b> [14] </b> Dinhanhthi (2021). Random forest [online] <br>
# Available at: https://dinhanhthi.com/random-forest/ [Accessed on 8th January 2021].
#
# <b>[15]  </b> Greg Doyle (2021). Chapter 8a Random Forest    [slides] <br>
# Available at: Blackboard.itcarlow.ie [Accessed on 26th January 2020.]
#
#
# <b> [16] </b> myGreatLearning (2021). Random Forest Algorithm -An overview [online] <br>
# Available at: https://www.mygreatlearning.com/blog/random-forest-algorithm/ [Accessed on 26th January 2021]
#
# <b> [17] </b>  Dhiraj K.Medium (2021). Random Forest Algorithm Advantages and Disadvantages [online] <br>
# Available at: https://dhirajkumarblog.medium.com/random-forest-algorithm-advantages-and-disadvantages-1ed22650c84f [Accessed on 27th January 2021]
#
# <b> [18] </b> TheProfessionalsPoint (2021). Advantages and Disadvantages of Random Forest Algorithm in Machine Learning [online] <br>
# Available at: http://theprofessionalspoint.blogspot.com/2019/02/advantages-and-disadvantages-of-random.html [Accessed on 27th January 2021].
#
# <b> [19] </b> MachineLearningMastery (2021). How to calculate feature importance with python [online] <br>
# Available at: https://machinelearningmastery.com/calculate-feature-importance-with-python/ [Accessed on 18th March 2021].
#
# <b> [20] </b> StackOverflow (2021). Plot trees for a Random Forest in Python with Scikit-Learn [online] <br>
# Available at: https://stackoverflow.com/questions/40155128/plot-trees-for-a-random-forest-in-python-with-scikit-learn [Accessed on 18th March 2021].
#
# <b> [21] </b> sklean.org (2021). sklearn.preprocessing.LabelEncoder [online] <br>
# Available at: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
#
# <hr>
#
# <h4> Some tutorials I used that helped me </h4>
#
# TowardsDataScience (2021). Random Forest in Python [online] <br>
# Available at: https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 [Accessed on 5th February].
#
# FreeCodeCamp (2021). Random Forest Classifier Tutorial: How to Use Tree-Based Algorithms for Machine Learnin [online] <br>
# Available at: https://www.freecodecamp.org/news/how-to-use-the-tree-based-algorithm-for-machine-learning/ [Accessed on 15th March 2021]

# %% [markdown]
# <hr>

# %% [markdown]
# ### Problem <a class="anchor" id="ProbRanFor"></a>

# %% [markdown]
# The problem that I have decided to work on for my Random Forest tutorial is regarding Stroke Predictions. The dataset that I have found has a series of data regarding Stroke predictions which will be discussed below.
#
# This problem is a very understandable issue and people will be able to understand all of the decisions in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Data Pre-processing <a class="anchor" id="DataRanFor"></a>

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pandas as pd
import os
from sklearn import tree
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# I will now display how I imported the dataset into this notebook. I will then move onto the handling of the null value, visualising the data and finally the main algorithm. The data can be downloaded from the link below. https://www.kaggle.com/fedesoriano/stroke-prediction-dataset

# %% [markdown]
# <hr>

# %% [markdown]
# #### Importing the dataset

# %% [markdown]
# <font color='red'>If the dataset is not getting imported correctly please change the path</font>

# %%
StrokePred = pd.read_csv('/home/jack/DataSolo/RandomForest/healthcare-dataset-stroke-data.csv')

# %%
StrokePred.shape

# %% [markdown]
# The cell above displays the shape of the dataset, this reads 5110 rows and 12 columns

# %%
StrokePred.dtypes

# %% [markdown]
# The cell above displays the DataTypes of each of the columns in the dataset.

# %%
StrokePred.head(5)

# %% [markdown]
# The columns in the dataset are as follows,
# - id – Identification Number.
# - gender – Male / Female.
# - age – age of individual
# - hypertension – 0 / 1
# - heart-disease – 0 / 1
# - ever_married – Yes / No.
# - work_type – Private / Self-Employed / Govt_job / Children.
# - Residence_Type – Urban / Rural.
# - avg_glucose_level – number
# - bmi – number.
# - smoking_status – formerly smoked / never smoked / smokes.
# - stroke – 1 / 0.

# %% [markdown]
# As you can see above from the ".head(5)" a sample of the first 5 rows of data. On line 1 you can see that the bmi level is "NaN". In the next section I will now demonstrate how to handle the null values.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Null Value Replacement

# %%
StrokePred.isnull().sum()

# %% [markdown]
# As can be seen in the cell above there is currently 201 null values in the bmi columns. There is multiple different methods on dealing with null values. A very obvious solution is to just drop the rows that contain the null values.
#
# But the way that we are going to take is the replacement route and that is because of the amount data our datasets contains.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Get average of the column

# %%
StrokePred['bmi'].mean()

# %% [markdown]
# As can be seen in the cells above the mean value of the "bmi" column.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Fill the Null values

# %%
StrokePred['bmi'] = StrokePred['bmi'].fillna(28.89)

# %%
StrokePred.head(5)

# %% [markdown]
# Now as you can see in the cell above, the null value that was on row 1 in the "bmi" column has been replaced with '28.89'. <br> This ws completed using the <b> .fillna() </b> method
#
# We will now move onto converting the string values to binary values.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
labels = LabelEncoder()
for s,d in zip(StrokePred,StrokePred.dtypes):
    if d == "object":
        StrokePred[s] = labels.fit_transform(StrokePred[s])

# %%
StrokePred.head(5)

# %% [markdown]
# As can be seen in the cells above the string decisions have now all been coverted to binary. <br> E.g. ever-married = <b> Yes </b> = 1 <b> No </b> = 0.
#
# This was completed using the LabelEncoder function along with a for loop. [21].

# %% [markdown]
# <hr>

# %% [markdown]
# #### Exploring the Data

# %% [markdown]
# I will now explore the dataset. This will inolve graphing and visualising some features against the main value in the dataset. The 2 features that I have chosen to compare the against the main value which is the stroke column are.
#
# - <b> Age </b> - The reasoning for choosing the age column is I will be able to visualise the stroke rates against the ages.
#
#
# - <b> Avg_Glucose_Level </b> - The reason for choosing the avg_glucose_level is is will be able to visualise the stroke rates against those with a high glucose(sugar) intake. According joslin.org a glucose less than 140 is normal anything above is dangerous

# %% [markdown]
# <hr>

# %% [markdown]
# #### Visualising the Age against Stroke levels

# %%
import seaborn as sb
import matplotlib as mpl
plt.figure(figsize=(12,6))
sb.histplot(x=StrokePred['age'], hue=StrokePred['stroke'], palette="dark")
plt.ylabel("Number of People this age")
plt.show()

# %% [markdown]
# As can be seen in the graph above
# - <b> 1 </b> = Yes (Had a Stroke)
# - <b> 0 </b> = No (Did not have a Stroke)
#
# As you can see in the new graph the stroke levels increases with age.
#
# We can now now move onto the avg_glucose_level and evaluate the data.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Visualising Stroke against avg_glocose_levels

# %%
plt.figure(figsize=(16,6))
sb.histplot(x=StrokePred['avg_glucose_level'], hue=StrokePred['stroke'], palette="dark")
plt.ylabel("Number of People this glucose level")
plt.show()

# %% [markdown]
# As can be seen in the graph above
# - <b> 1 </b> = Yes (Had a Stroke)
# - <b> 0 </b> =  No (Did not have a Stroke)
#
# As you can see in the new graph the stroke levels do increase with a high glucose level. The Gap between the number of people with 100 average glucose level and people who have had a storke is high.
#
# But as the glucose level increases the gap between the number of peeople with 200 average glucose levels is drastically different to 100.
#
# A conclusion can be constructed from this graph in that the higher your glucose level is the more likely you are to having a storke.

# %% [markdown]
# I will now move onto implementing the Random forest algorithm.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Main Algorithm <a class="anchor" id="MainRanFor"></a>

# %% [markdown]
# <hr>

# %% [markdown]
# #### Splitting the Data

# %%
features = ['gender', 'age', 'hypertension','heart_disease', 'ever_married','work_type','Residence_type','avg_glucose_level','bmi', 'smoking_status']
X = StrokePred[features]
y = StrokePred.stroke
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %% [markdown]
# As you can see in the cell above I set the
#
#    - <b> X </b> = features of the dataset
#    - <b> y </b> = stroke
#
# I then pass the X and y variables into the <b> train_test_split </b> function, like will split the variables using the test_size parameter that I set.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Training the Model & Accuracy

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100, random_state = 0, max_depth=3)
rf.fit(X_train, y_train);
y_pred = rf.predict(X_test)

# %%
from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred) *100)

# %% [markdown]
# As you can see in the cells above I have trained the model using RandomForestClassifier and setting the parameters.
#
# I then fit the X_train and y_train values and stored it in the <b> y_pred </b> variable.
#
# After executing this model I received an accuracy of <b> 94 % </b> .
# <br> This is a very good result!

# %% [markdown]
# <hr>

# %% [markdown]
# #### Feature Importance

# %% [markdown]
# Before moving on I am going to take a look at the feature important of my model. The following cells will displays how this is found. [19]

# %%
importance = rf.feature_importances_
plt.figure(figsize=(18,6))
plt.bar([x for x in range(len(importance))], importance)
y_pos = np.arange(len(features))
plt.xticks(y_pos,features)
plt.show()

# %% [markdown]
# As you can see in the graph above the feature important that has been generated from the model.
#
# This graph shows the most influencial features, the bmi and the avg_glucose_level are clearly the main features.
#
# We were correct earlier on in the algorithm by assuming that the age and avg_glucose_level would be important features.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Visualising the Random forest

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 5,figsize = (10,2), dpi=900)
for i in range(0,5):
    tree.plot_tree(rf.estimators_[i],
                   ax = axes[i]);
    axes[i].set_title('Estimator: ' + str(i), fontsize = 11)

# %% [markdown]
# As you can see in the graphs above, its is a sample of the first 5 Decision trees that have been created from the RandomForestClassifier class. [20]
#
# I will now attempt to re-model the parameters of the RandomForestClassifier class, these can be found at this link : https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %% [markdown]
# <hr>

# %% [markdown]
# #### Re-model the Parameters

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 20, random_state = 1, max_depth=3, criterion="entropy", min_samples_split=2,min_samples_leaf=2,max_samples=3)
rf.fit(X_train, y_train);
y_pred = rf.predict(X_test)

# %%
from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred) *100)

# %% [markdown]
# As you can be from the accuray above of <b> 94 %</b> . I could not increase the accuracy by re-modeling the parameters.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Conclusion + Quality <a class="anchor" id="ConRanFor"></a>

# %% [markdown]
# <hr>

# %% [markdown]
# In conclusion, the Random forest algorithm is an accurate and easy to use algorithm. The implementation that Random Forest has on python really makes it very easy to get an accurate prediction.
#
# The random forest algorithm is a very accessible algorithm as it can run both classification and regression problems.
#
# Overall I believe that random forest is a great algorithm to use if you have a lot of binary data.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Neural Networks<a class="anchor" id="NeuralNetworks"></a>
# * [Introduction](#IntroNN)
# * [Sources Of Information](#InfoNN)
# * [Problem](#ProbNN)
# * [Data Pre-processing](#DataNN)
# * [Main Algorithm](#MainNN)
# * [Conclusion + Quality](#ConNN)

# %% [markdown]
# #### Introduction <a class="anchor" id="IntroNN"></a>

# %% [markdown]
# #### Sources Of Information <a class="anchor" id="InfoNN"></a>

# %% [markdown]
# #### Problem <a class="anchor" id="ProbNN"></a>

# %% [markdown]
# #### Data Pre-processing <a class="anchor" id="DataNN"></a>

# %% [markdown]
# #### Main Algorithm <a class="anchor" id="MainNN"></a>

# %% [markdown]
# #### Conclusion + Quality <a class="anchor" id="ConNN"></a>

# %% [markdown]
# <hr>

# %% [markdown]
# ### K-Nearest-Neighbour<a class="anchor" id="KNN"></a>
# * [Introduction](#IntroKNN)
# * [Sources Of Information](#InfoKNN)
# * [Problem](#ProbKNN)
# * [Data Pre-processing](#DataKNN)
# * [Main Algorithm](#MainKNN)
# * [Conclusion + Quality](#ConKNN)

# %% [markdown]
# #### Introduction <a class="anchor" id="IntroLR"></a>

# %% [markdown]
# #### Sources Of Information<a class="anchor" id="InfoLR"></a>

# %% [markdown]
# #### Problem <a class="anchor" id="ProbKNN"></a>

# %% [markdown]
# #### Data Pre-processing <a class="anchor" id="DataLR"></a>

# %% [markdown]
# #### Main Algorithm <a class="anchor" id="MainLR"></a>

# %% [markdown]
# #### Conclusion + Quality <a class="anchor" id="ConLR"></a>

# %% [markdown]
# <hr>

# %% [markdown]
# ### Conclusion<a class="anchor" id="Conclusion"></a>

# %% [markdown]
# ### Declaration<a class="anchor" id="Declaration"></a>
